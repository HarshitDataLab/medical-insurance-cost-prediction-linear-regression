# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\ML Project 11 Medical Insurance Cost Prediction using Linear Regression Model\insurance.csv")

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.shape
# Out:
# (1338, 7)

# %%
data['region'].unique()
# Out:
# <ArrowStringArray>
# ['southwest', 'southeast', 'northwest', 'northeast']
# Length: 4, dtype: str

# %%
data['smoker'].unique()
# Out:
# <ArrowStringArray>
# ['yes', 'no']
# Length: 2, dtype: str

# %%
data = data.replace({
    'sex':{'male':1, 'female':0},
    'region':{'southwest':0, 'southeast':1, 'northwest':2, 'northeast':3},
    'smoker':{'yes':1, 'no':0}
})

# %%
data.head()
# Out:
#    age sex     bmi  children smoker region      charges
# 0   19   0  27.900         0      1      0  16884.92400
# 1   18   1  33.770         1      0      1   1725.55230
# 2   28   1  33.000         3      0      1   4449.46200
# 3   33   1  22.705         0      0      2  21984.47061
# 4   32   1  28.880         0      0      2   3866.85520

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.distplot(data['age'])
plt.show()
# Out:
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_3780\3668578308.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'])

# %%
sns.countplot(x='sex', data=data, palette='viridis')
plt.show()
# Out:
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_3780\695996627.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=data, palette='viridis')

# %%
sns.distplot(data['bmi'])
plt.show()
# Out:
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_3780\1978922521.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['bmi'])

# %%
sns.countplot(x='children', data=data, palette='viridis')
plt.show()
# Out:
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_3780\1645322272.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='children', data=data, palette='viridis')

# %%
sns.countplot(x='smoker', data=data, palette='viridis')
plt.show()
# Out:
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_3780\2519442568.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='smoker', data=data, palette='viridis')

# %%
sns.countplot(x='region', data=data, palette='viridis')
plt.show()
# Out:
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_3780\1730337719.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='region', data=data, palette='viridis')

# %%
sns.distplot(data['charges'])
plt.show()
# Out:
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_3780\572635637.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['charges'])

# %%
x = data.iloc[:,:-1]

# %%
x
# Out:
#       age sex     bmi  children smoker region
# 0      19   0  27.900         0      1      0
# 1      18   1  33.770         1      0      1
# 2      28   1  33.000         3      0      1
# 3      33   1  22.705         0      0      2
# 4      32   1  28.880         0      0      2
# ...   ...  ..     ...       ...    ...    ...
# 1333   50   1  30.970         3      0      2
# 1334   18   0  31.920         0      0      3
# 1335   18   0  36.850         0      0      1
# 1336   21   0  25.800         0      0      0
# 1337   61   0  29.070         0      1      2
#
# [1338 rows x 6 columns]

# %%
y = data['charges']

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x.shape, x_train.shape, x_test.shape
# Out:
# ((1338, 6), (1070, 6), (268, 6))

# %%
 y_train.shape, y_test.shape
# Out:
# ((1070,), (268,))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(
    fit_intercept=True,
    n_jobs=-1
)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
model.score(x_train, y_train)*100
# Out:
# 74.1704928323398

# %%
model.score(x_test, y_test)*100
# Out:
# 78.33463107364538

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

pred = model.predict(x_test)

print("MAE :", mean_absolute_error(y_test, pred))
print("MSE :", mean_squared_error(y_test, pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, pred)))
print("R² Score:", r2_score(y_test, pred))
# Out:
# MAE : 4186.508898366432
# MSE : 33635210.4311784
# RMSE: 5799.587091438355
# R² Score: 0.7833463107364539

# %%
new_data = pd.DataFrame([[
    28,
    1,
    33.000,
    3,
    0,
    1
]], columns=x.columns)

prediction = model.predict(new_data)
print(prediction)
# Out:
# [7045.67239673]

# %%
import pickle

pickle.dump(model, open('Medical_insurance_cost_prediction.sav', 'wb'))
